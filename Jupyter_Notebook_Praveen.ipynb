# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# # Data Science Tools and Ecosystem
#
# ![2-title.png](attachment:97ca9a75-dd21-4f2c-aad3-74b6e80a7bf7.png)

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystem are summarized.
#
# ![3-intro.png](attachment:bd78cc15-99ef-42e0-8a99-f574f2ca4707.png)

# %% [markdown]
# # Some of the popular languages that Data Scientists use are:
#
# # Ordered List
#  # 1.Python
#  # 2.R
#  # 3.Scala
#  # 4.SQL
#
#  ![4-dslanguages.png](attachment:89956754-9e02-432d-a0dc-1c4843930289.png)

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
#
# # List of Libraries
#
# # 1.Numpy
# # 2.pandas
# # 3.mapplotlib
# # 4.Scikit-learn
# # 5.Tersonflow
# # 6.Seaborn
#
# ![5-dslibraries.png](attachment:3f7bf005-3f94-4f5c-aae5-5176dfa02817.png)

# %% [markdown]
# # Data Science Tools
#
# |Data Science Tools|
# |------------------|
# | SQL              |
# | Pandas           |
# | Tableau          |
# | Numpy            |
# | Matplotlib       |
# | RStudio          |
# | TensorFlow       |
#
# ![6-dstools.png](attachment:a240b181-b50d-4eb1-918a-a6f853547b3d.png)

# %% [markdown]
# # Below are a few examples of evaluating arithmetic expressions in Python.

# %%
a = 23
b = 34

print ('Addition of numbers 23 and 34')

print (a + b)


(3*4)+5
# Out:
# Addition of numbers 23 and 34
# 57
# 17

# %% [markdown]
# ![7-introarithmetic.png](attachment:10c4d3da-47bf-4b66-96aa-335ddeefac14.png)

# %% [markdown]
# # This a simple arithmetic expression to mutiply then add integers

# %%
print ('Multiplication of numbers 3 and 4 and then addition of  5 to it')
print ((3*4)+5)
# Out:
# Multiplication of numbers 3 and 4 and then addition of  5 to it
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:156f7e81-f807-477d-9376-6ef36fe69834.png)

# %% [markdown]
# # This will convert 200 minutes to hours by diving by 60.

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:ade676af-7b7e-4280-a1b0-809d090de371.png)

# %% [markdown]
# # Some of the key takeaways from the course
# **Objectives :**
#
# - Create a Jupyter Notebook
# - Create markdown cell with title of the notebook
# - Create a markdown cell for an introduction
# - Create a markdown cell to list data science languages
# - Create a markdown cell to list data science libraries
# - Create a markdown cell with a table of Data Science tools
# - Create a markdown cell introducing arithmetic expression examples
# - Create a code cell to multiply and add numbers
# - Create a code cell to convert minutes to hours
# - Insert a markdown cell to list Objectives

# %% [markdown]
# ![10-objectives.png](attachment:af7eb148-ded0-4ef7-a58f-b381fdafffbc.png)

# %% [markdown]
# ## Author
#
# Praveen Kumar Sakrepatna Lokesha

# %% [markdown]
# ![11-authordetails.png](attachment:7e331c4f-bae7-4540-91dd-ceafe1591109.png)

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
