# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# # In this notebook, Data Science Tools and Ecosystem are summarized.
#
# ![2-title.png](attachment:895d8158-380d-4e05-8cd2-e7cf0e459fa5.png)

# %% [markdown]
# # Some of the popular languages that Data Scientists use are:
#
# # Ordered List
#  # 1.Python
#  # 2.R
#  # 3.Scala
#  # 4.SQL

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
#
# # List of Libraries
#
# # 1.Numpy
# # 2.pandas
# # 3.mapplotlib
# # 4.Scikit-learn
# # 5.Tersonflow
# # 6.Seaborn
#
# ![6-dstools.png](attachment:87687dd3-f8ce-45d3-98f4-ebc5e1e8d124.png)

# %% [markdown]
# # Data Science Tools
#
# |Data Science Tools|
# |------------------|
# | SQL              |
# | Pandas           |
# | Tableau          |
# | Numpy            |
# | Matplotlib       |
# | RStudio          |
# | TensorFlow       |
#
# ![6-dstools.png](attachment:805e5488-9053-4de0-bc9c-afd036462c8b.png)

# %% [markdown]
# # Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# ![7-introarithmetic.png](attachment:e96325dc-121f-41c8-9d88-45d33b947726.png)

# %%
a = 23
b = 34

print ('Addition of numbers 23 and 34')

print (a + b)


(3*4)+5
# Out:
# Addition of numbers
# 57
# 17

# %% [markdown]
# # This a simple arithmetic expression to mutiply then add integers

# %%
print ('Multiplication of numbers 3 and 4 and then addition of  5 to it')
print ((3*4)+5)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:a34734cc-204e-4319-95ce-10dee25305b7.png)

# %% [markdown]
# # This will convert 200 minutes to hours by diving by 60.

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.png](attachment:ff78afa7-09f2-4dbb-84fc-c95d5b8db89b.png)

# %% [markdown]
# # Some of the key takeaways from the course
# **Objectives :**
#
# - Create a Jupyter Notebook
# - Create markdown cell with title of the notebook
# - Create a markdown cell for an introduction
# - Create a markdown cell to list data science languages
# - Create a markdown cell to list data science libraries
# - Create a markdown cell with a table of Data Science tools
# - Create a markdown cell introducing arithmetic expression examples
# - Create a code cell to multiply and add numbers
# - Create a code cell to convert minutes to hours
# - Insert a markdown cell to list Objectives

# %% [markdown]
# ![10-objectives.png](attachment:d2b973e0-428f-47b5-a166-3988e3437225.png)

# %% [markdown]
# ## Author
#
# Praveen Kumar Sakrepatna Lokesha

# %% [markdown]
# ![11-authordetails.png](attachment:8e526876-5f96-47fe-9df9-9b06b7817057.png)
